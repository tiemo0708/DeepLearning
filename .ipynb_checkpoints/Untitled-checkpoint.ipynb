# %%
import json

import networkx as nx

# %matplotlib inline
# Out:
#   File "<ipython-input-8-e0cf9ea6832e>", line 2
#     import json
#     ^
# IndentationError: unexpected indent

# %%
import numpy as np
x = np.array([1.0, 2.0, 3.0])
print(x)
# Out:
# [1. 2. 3.]

# %%
g = nx.karate_club_graph()
plt.figure(figsize=(6,4));
nx.draw(g)
